# %%
import os
import cv2
import cvlib as cv
from PIL import Image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.models import load_model
import numpy as np
from matplotlib import pyplot as plt
from mtcnn import MTCNN
# from keras.utils import np_utils
from keras import utils

from sklearn.metrics import f1_score as sklearn_f1_score

# %%
from PIL import Image
import os

def process_images(images_folder, labels_folder, output_folder):
    # Make the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate over each file in the image directory
    for img_name in os.listdir(images_folder):
        if img_name.endswith(".jpeg") or img_name.endswith(".png"):
            # Derive the corresponding label filename
            label_name = img_name.rsplit('.', 1)[0] + '.txt'

            # Create paths for the image and label
            img_path = os.path.join(images_folder, img_name)
            label_path = os.path.join(labels_folder, label_name)

            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    coords = f.readline().strip().split()
                    if len(coords) == 5:
                        class_id, x_center, y_center, width, height = coords
                        with Image.open(img_path) as img:
                            img_width, img_height = img.size
                            x_center, y_center, width, height = float(x_center), float(y_center), float(width), float(height)

                            # Convert normalized coordinates to pixel values
                            x_center *= img_width
                            y_center *= img_height
                            width *= img_width
                            height *= img_height

                            # Convert center coordinates to top-left and bottom-right
                            x1, y1 = int(x_center - width/2), int(y_center - height/2)
                            x2, y2 = int(x_center + width/2), int(y_center + height/2)

                            # Crop the image
                            cropped_img = img.crop((x1, y1, x2, y2))
                            cropped_img.save(os.path.join(output_folder, img_name))
                    else:
                        print(f"Unexpected format in {label_path}. Contents: {coords}")


if __name__ == "__main__":
    images_folder = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data" \
                    "/big/archive (2)/weapon_detection/train/images"
    labels_folder = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data" \
                    "/big/archive (2)/weapon_detection/train/labels"
    output_folder = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data" \
                    "/big/archive (2)/weapon_detection/train/cropped"

    process_images(images_folder, labels_folder, output_folder)

# %%
from PIL import Image
import numpy as np
import os
import imgaug.augmenters as iaa

# Define your desired image size
TARGET_SIZE = (224, 224)

# Define the augmentation sequence
# augmenter = iaa.Sequential([
#     iaa.Fliplr(0.5),  # Horizontal flips
#     iaa.Affine(
#         scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},  # Scaling
#         translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # Translation
#         rotate=(-30, 30),  # Rotation
#         shear=(-16, 16)  # Shearing
#     ),
#     iaa.PerspectiveTransform(scale=(0.01, 0.15)),  # Perspective transformations
#     iaa.Multiply((0.8, 1.2)),  # Change brightness
#     iaa.ContrastNormalization((0.7, 1.3)),  # Change contrast
#     iaa.GaussianBlur(sigma=(0, 3.0)),  # Gaussian Blur
#     iaa.AdditiveGaussianNoise(scale=(0, 0.05*255)),  # Noise
#     iaa.Crop(percent=(0, 0.1)),  # Random cropping
#     iaa.LinearContrast((0.7, 1.3)),  # Improve or worsen contrast
#     iaa.ChangeColorspace(to_colorspace="GRAY"),  # Convert images to grayscale
#     iaa.ElasticTransformation(alpha=50, sigma=5)  # Elastic transformations
# ])

augmenters = [
    iaa.Fliplr(0.5),  # Horizontal flips
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},  # Scaling
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # Translation
        rotate=(-30, 30),  # Rotation
        shear=(-16, 16)  # Shearing
    ),
    iaa.PerspectiveTransform(scale=(0.01, 0.15)),  # Perspective transformations
    iaa.Multiply((0.8, 1.2)),  # Change brightness
    iaa.ContrastNormalization((0.7, 1.3)),  # Change contrast
    iaa.GaussianBlur(sigma=(0, 3.0)),  # Gaussian Blur
    iaa.AdditiveGaussianNoise(scale=(0, 0.05*255)),  # Noise
    iaa.Crop(percent=(0, 0.1)),  # Random cropping
    iaa.LinearContrast((0.7, 1.3)),  # Improve or worsen contrast
    iaa.ChangeColorspace(to_colorspace="GRAY"),  # Convert images to grayscale
    iaa.ElasticTransformation(alpha=50, sigma=5)  # Elastic transformations
]

def resize_image(image, target_size):
    return image.resize(target_size)


def apply_augmentation(image, augmenter):
    # Convert PIL image to numpy array
    image_np = np.array(image)
    # Apply the augmentation
    image_aug = augmenter(image=image_np)
    # Convert back to PIL Image
    return Image.fromarray(image_aug)

def process_images(images_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for img_name in os.listdir(images_folder):
        if img_name.endswith((".jpeg", ".png", ".jpg")):
            img_path = os.path.join(images_folder, img_name)
            with Image.open(img_path).convert('RGB') as img:
                img_resized = resize_image(img, TARGET_SIZE)
                for idx, augmenter in enumerate(augmenters):
                    img_augmented = apply_augmentation(img_resized, augmenter)
                    # Generate a unique name for each augmented image
                    base_name, ext = os.path.splitext(img_name)
                    new_name = f"{base_name}_aug{idx}{ext}"
                    img_augmented.save(os.path.join(output_folder, new_name))


if __name__ == "__main__":
    images_folder = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data" \
                    "/big/knives"
    output_folder = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data" \
                    "/big/knives/augmented_2"

    process_images(images_folder, output_folder)

# %%
"""
Resizing Cropped Images and save them
"""
def resize_image(input_dir,output_dir):

    # specify the new dimensions you want for the images
    new_dimensions = (40, 40)  # you should change this to the dimensions you want

    # create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # add/modify image file types here
            img = Image.open(os.path.join(input_dir, filename))
            img.thumbnail(new_dimensions)
            img.save(os.path.join(output_dir, filename))

resize_image("C:/Users/mupaj/Documents/Apps/final_vc/FaceData/man_croped/","C:/Users/mupaj/Documents/Apps/final_vc/FaceData/man_resized/")

resize_image("C:/Users/mupaj/Documents/Apps/final_vc/FaceData/woman_croped/","C:/Users/mupaj/Documents/Apps/final_vc/FaceData/woman_resized/")

# %%
"""
Find F1 Score
"""

def compute_f1_score(test_generator, model):

    # Generate a list of labels
    test_labels = test_generator.classes
    # Convert the labels to categorical
    test_labels = utils.to_categorical(test_labels, num_classes=len(test_generator.class_indices))

    # Make the model predictions
    predictions = model.predict(test_generator)

    # Convert predictions classes to one hot vectors
    predicted_classes = np.argmax(predictions, axis=1)
    # Convert test observations to one hot vectors
    true_classes = np.argmax(test_labels, axis=1)

    # compute the confusion matrix
    f1Score = sklearn_f1_score(true_classes, predicted_classes, average='macro')

    print("F1 Score: ", f1Score)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2  # OpenCV for heatmap processing

def generate_heatmap(img_path, model, output_name="heatmap.jpg"):
    # Preprocess the image
    img = cv2.imread(img_path)
    img = cv2.resize(img, (150, 150))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_tensor = np.expand_dims(img, axis=0)
    img_tensor = img_tensor.astype('float32') / 255.  # Correct datatype for model-specific preprocessing method

    # Get the model's prediction
    preds = model.predict(img_tensor)
    predicted_class = np.argmax(preds[0])

    # Extract the output of the last convolutional layer in the model
    last_conv_layer = model.get_layer(index=-4)  # Assuming it's the last conv layer

    # Compute the gradient of the class' output value with respect to the feature map
    with tf.GradientTape() as tape:
        last_conv_layer_output = last_conv_layer(img_tensor)
        tape.watch(last_conv_layer_output)
        class_channel = model.layers[-1](last_conv_layer_output)
        loss = class_channel[:, predicted_class]

    grads = tape.gradient(loss, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Multiply each channel in the feature map array by the gradient importance
    last_conv_layer_output = last_conv_layer_output.numpy()[0]
    for i in range(last_conv_layer_output.shape[-1]):
        last_conv_layer_output[:, :, i] *= pooled_grads[i]

    # Average the feature maps along the channel dimension resulting in a heatmap of size 3x3
    heatmap = np.mean(last_conv_layer_output, axis=-1)

    # Normalize the heatmap between 0 & 1 for visualization
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

    # Superimpose the heatmap over the original image
    superimposed_img = heatmap * 0.4 + img

    # Save the image with the specified name
    cv2.imwrite(output_name, superimposed_img.astype('uint8'))

    # Display the image (optional)
    plt.imshow(superimposed_img.astype('uint8'))
    plt.show()


# # Usage:
# img_path = "path_to_an_image.jpg"
# generate_heatmap(img_path, model)

# %%
ROOT_DIR = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big" \
           "/weapons/weapon_detection/train/"

# %%
import pandas as pd


def f1_score(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))


def generate_heatmaps_for_images(img_paths, model, epoch):
    for idx, img_path in enumerate(img_paths):
        print(img_paths)
        output_name = f"{ROOT_DIR}heatmap_epoch_{epoch}_img_{idx}.jpg"
        generate_heatmap(img_path, model, output_name)

        plt.savefig(f"{ROOT_DIR}CCCCheatmap_epoch_{epoch}_img_{idx}.png")
        plt.show()

import seaborn as sns  # You might need to install seaborn using pip

# def plot_confusion_matrix(conf_matrix, labels):
#     plt.figure(figsize=(10,7))
#     sns.heatmap(conf_matrix, annot=True, cmap="YlGnBu", fmt="g",
#                 xticklabels=labels, yticklabels=labels)
#     plt.xlabel('Predicted')
#     plt.ylabel('True')
#     plt.title('Confusion Matrix')
#     plt.savefig('confusion_matrix.png')
#     plt.show()

def save_matrix_to_csv(conf_matrix, epoch, filename=f"{ROOT_DIR}confusion_matrices.csv"):
    # Convert matrix to DataFrame for easier CSV storage
    df = pd.DataFrame(conf_matrix)

    # Add a column to specify the epoch number
    df['epoch'] = epoch

    # If file doesn't exist, create one. Otherwise, append without writing the header again.
    if not os.path.isfile(filename):
        df.to_csv(filename, index=False)
    else:
        df.to_csv(filename, mode='a', header=False, index=False)

def plot_combined_confusion_matrices_from_csv(labels,
                                              filename=f"{ROOT_DIR}confusion_matrices"
                                                       ".csv"):
    # Read the saved CSV
    data = pd.read_csv(filename)

    total_epochs = data['epoch'].nunique()

    plt.figure(figsize=(15, 7*total_epochs))

    for i, epoch in enumerate(data['epoch'].unique()):
        conf_matrix = data[data['epoch'] == epoch].drop('epoch', axis=1).values
        plt.subplot(total_epochs, 1, i+1)
        sns.heatmap(conf_matrix, annot=True, cmap="YlGnBu", fmt="g",
                    xticklabels=labels, yticklabels=labels)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title(f'Confusion Matrix - Epoch {epoch}')

    plt.tight_layout()
    plt.savefig(f'{ROOT_DIR}combined_confusion_matrices.png')
    plt.show()

# %%
import os
import csv
import time
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K


def train_model(dataset_dir):

    # ImageDataGenerator for data augmentation and rescaling
    datagen = ImageDataGenerator(rescale=1. / 255, validation_split=0.2) # assuming 20% validation split

    train_generator = datagen.flow_from_directory(
        dataset_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical',
        subset='training',
        seed=42)  # reproducible split


    validation_generator = datagen.flow_from_directory(
        dataset_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical',
        subset='validation')

    # You may want to create another ImageDataGenerator for test without data augmentation later

    # Model creation
    # Create the model architecture.
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    # model.add(Dense(128, activation='relu'))
    # Now add your dense layers
    model.add(Dense(128, activation='relu'))
    model.add(Dense(len(train_generator.class_indices), activation='softmax'))

    # Compile the model.
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model.
    model.fit(train_generator, validation_data=validation_generator,
              epochs=100, batch_size=32)

    # Compilation
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', f1_score])

    # CSV for results
    with open(f"{ROOT_DIR}results.csv", "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Epoch", "Accuracy", "Loss", "F1 Score", "Validation Accuracy", "Validation Loss", "Validation F1 Score", "Time (seconds)"])

        # Training and data collection
        for epoch in range(1, 101):  # for 5 epochs, adjust as necessary
            start_time = time.time()
            history = model.fit(train_generator, validation_data=validation_generator, epochs=epoch,
                                initial_epoch=epoch-1, batch_size=32, verbose=1)
            end_time = time.time()

            # Saving epoch data to CSV
            writer.writerow([epoch,
                 history.history['accuracy'][-1],
                 history.history['loss'][-1],
                 history.history['f1_score'][-1],
                 history.history['val_accuracy'][-1],
                 history.history['val_loss'][-1],
                 history.history['val_f1_score'][-1],
                 end_time - start_time])

            # Plotting accuracy and loss after each epoch
            plt.figure(figsize=(12, 5))
            plt.subplot(1, 2, 1)
            plt.plot(history.history['accuracy'], label='Train Accuracy')
            plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
            plt.legend()
            plt.title(f"Epoch {epoch} Accuracy")

            plt.subplot(1, 2, 2)
            plt.plot(history.history['loss'], label='Train Loss')
            plt.plot(history.history['val_loss'], label='Validation Loss')
            plt.legend()
            plt.title(f"Epoch {epoch} Loss")

            plt.savefig(f"{ROOT_DIR}epoch_{epoch}_plot.png")
            # plt.show()


    y_true = validation_generator.classes
    predictions = model.predict(validation_generator)
    y_pred = np.argmax(predictions, axis=1)

    # Step 3: Compute the confusion matrix
    from sklearn.metrics import confusion_matrix
    # Step 3: Compute the confusion matrix
    conf_matrix = confusion_matrix(y_true, y_pred)

    # Step 4: Save the matrix to CSV and then plot from the CSV
    save_matrix_to_csv(conf_matrix, epoch)
    plot_combined_confusion_matrices_from_csv(list(train_generator.class_indices.keys()))


    # Heatmaps or feature visualizations are a bit more involved and may be implemented separately.
    # Saving the final model
    model.save('model_NOOICE.h5')

    img_paths = ["C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big"
                 "/weapons/weapon_detection/train/augmented_2/guns/032_aug7"
                 ".jpg",
                 # "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big"
                 # "/weapons/weapon_detection/terrorists2.jpg",
                 # "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big"
                 # "/weapons/weapon_detection/Depositphotos_18373785_S.jpg",
                 # "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big"
                 # "/weapons/weapon_detection/BN-NE957_0322BE_M_20160322103251"
                 # ".jpg",
                 # "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big"
                 # "/weapons/weapon_detection/1b68af-20170106-airport02.jpg"
                 ]
    # add paths
    # to the
    # representative images
    # For demonstration, let's generate heatmaps at the end of training.
    # However, you could call this function at any epoch if desired.
    # generate_heatmaps_for_images(img_paths, model, epoch)

    return train_generator, validation_generator, model


# Usage:
train_generator, validation_generator, model = train_model\
    ("C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big"
                 "/weapons/weapon_detection/train/augmented_2")
# Out:
# Found 9394 images belonging to 2 classes.
# Found 2348 images belonging to 2 classes.
# Epoch 1/100
# 294/294 [==============================] - 120s 407ms/step - loss: 0.2984 - accuracy: 0.8797 - val_loss: 0.5519 - val_accuracy: 0.7802
# Epoch 2/100
# 294/294 [==============================] - 121s 411ms/step - loss: 0.1196 - accuracy: 0.9572 - val_loss: 0.5525 - val_accuracy: 0.7900
# Epoch 3/100
# 294/294 [==============================] - 111s 377ms/step - loss: 0.0514 - accuracy: 0.9833 - val_loss: 0.9943 - val_accuracy: 0.7496
# Epoch 4/100
# 294/294 [==============================] - 95s 324ms/step - loss: 0.0330 - accuracy: 0.9897 - val_loss: 0.7851 - val_accuracy: 0.8028
# Epoch 5/100
# 294/294 [==============================] - 94s 319ms/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 1.2642 - val_accuracy: 0.7526
# Epoch 6/100
# 294/294 [==============================] - 92s 313ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 1.4956 - val_accuracy: 0.7739
# Epoch 7/100
# 294/294 [==============================] - 92s 313ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 1.3391 - val_accuracy: 0.7811
# Epoch 8/100
# 294/294 [==============================] - 92s 311ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 1.1058 - val_accuracy: 0.8020
# Epoch 9/100
# 294/294 [==============================] - 91s 309ms/step - loss: 0.0222 - accuracy: 0.9921 - val_loss: 1.0281 - val_accuracy: 0.7909
# Epoch 10/100
# 294/294 [==============================] - 91s 309ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 1.5267 - val_accuracy: 0.7875
# Epoch 11/100
# 294/294 [==============================] - 90s 308ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 1.4483 - val_accuracy: 0.7866
# Epoch 12/100
# 294/294 [==============================] - 91s 308ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 1.8340 - val_accuracy: 0.7909
# Epoch 13/100
# 294/294 [==============================] - 91s 309ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 2.2411 - val_accuracy: 0.7291
# Epoch 14/100
# 294/294 [==============================] - 91s 309ms/step - loss: 0.0203 - accuracy: 0.9934 - val_loss: 1.4993 - val_accuracy: 0.7747
# Epoch 15/100
# 294/294 [==============================] - 91s 311ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss:
-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.1851 - val_accuracy: 0.7875 - val_f1_score: 0.7872
# Epoch 89/89
# 294/294 [==============================] - 89s 304ms/step - loss: 1.1156e-05 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2474 - val_accuracy: 0.7858 - val_f1_score: 0.7862
# Epoch 90/90
# 294/294 [==============================] - 90s 306ms/step - loss: 6.7761e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2561 - val_accuracy: 0.7866 - val_f1_score: 0.7863
# Epoch 91/91
# 294/294 [==============================] - 89s 304ms/step - loss: 4.8858e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.2997 - val_accuracy: 0.7862 - val_f1_score: 0.7866
# Epoch 92/92
# 294/294 [==============================] - 90s 307ms/step - loss: 3.6988e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3311 - val_accuracy: 0.7866 - val_f1_score: 0.7863
# Epoch 93/93
# 294/294 [==============================] - 89s 304ms/step - loss: 2.7950e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3706 - val_accuracy: 0.7853 - val_f1_score: 0.7843
# Epoch 94/94
# 294/294 [==============================] - 89s 304ms/step - loss: 2.0986e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.3857 - val_accuracy: 0.7858 - val_f1_score: 0.7862
# Epoch 95/95
# 294/294 [==============================] - 90s 305ms/step - loss: 1.6127e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4168 - val_accuracy: 0.7824 - val_f1_score: 0.7828
# Epoch 96/96
# 294/294 [==============================] - 90s 306ms/step - loss: 1.2738e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4185 - val_accuracy: 0.7828 - val_f1_score: 0.7832
# Epoch 97/97
# 294/294 [==============================] - 91s 308ms/step - loss: 1.0510e-06 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4532 - val_accuracy: 0.7807 - val_f1_score: 0.7804
# Epoch 98/98
# 294/294 [==============================] - 90s 307ms/step - loss: 8.6184e-07 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4830 - val_accuracy: 0.7798 - val_f1_score: 0.7796
# Epoch 99/99
# 294/294 [==============================] - 90s 305ms/step - loss: 7.1465e-07 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.4878 - val_accuracy: 0.7794 - val_f1_score: 0.7798
# Epoch 100/100
# 294/294 [==============================] - 90s 306ms/step - loss: 5.9909e-07 - accuracy: 1.0000 - f1_score: 1.0000 - val_loss: 2.5045 - val_accuracy: 0.7794 - val_f1_score: 0.7805
# 74/74 [==============================] - 4s 49ms/step
# C:\Users\mupaj\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_metrics_from_csv(csv_path):
    # Read the CSV
    data = pd.read_csv(csv_path)

    epochs = data['Epoch'].values

    # Plot Accuracy
    plt.figure(figsize=(12, 5))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, data['Accuracy'].values, label='Train Accuracy', marker='o', color='blue')
    plt.plot(epochs, data['Validation Accuracy'].values, label='Validation Accuracy', marker='o', color='green')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, data['Loss'].values, label='Train Loss', marker='o', color='red')
    plt.plot(epochs, data['Validation Loss'].values, label='Validation Loss', marker='o', color='orange')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()
    plt.savefig(f"model_accuracy_and_loss_.png")

    # Separate plot for F1 Score
    plt.figure(figsize=(6, 5))
    plt.plot(epochs, data['F1 Score'].values, label='Train F1 Score', marker='o', color='purple')
    plt.plot(epochs, data['Validation F1 Score'].values, label='Validation F1 Score', marker='o', color='pink')
    plt.title('F1 Score over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()
    plt.show()
    plt.savefig(f"f1_score.png")

# Usage:
csv_path = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big" \
           "/weapons/weapon_detection/train/results.csv"  # Replace with
# your CSV path
plot_metrics_from_csv(csv_path)

# %%
import pandas as pd

def compute_averages_and_sum(csv_path):
    # Read the CSV
    data = pd.read_csv(csv_path)

    # Compute averages
    avg_accuracy = data['Accuracy'].mean()
    avg_loss = data['Loss'].mean()
    avg_f1_score = data['F1 Score'].mean()
    avg_val_accuracy = data['Validation Accuracy'].mean()
    avg_val_loss = data['Validation Loss'].mean()
    avg_val_f1_score = data['Validation F1 Score'].mean()

    # Compute total time
    total_time = data['Time (seconds)'].sum()

    print("Average Training Accuracy:", avg_accuracy)
    print("Average Training Loss:", avg_loss)
    print("Average Training F1 Score:", avg_f1_score)
    print("Average Validation Accuracy:", avg_val_accuracy)
    print("Average Validation Loss:", avg_val_loss)
    print("Average Validation F1 Score:", avg_val_f1_score)
    print("Total Training Time (seconds):", total_time)

# Usage:
csv_path = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big" \
           "/weapons/weapon_detection/train/results.csv"  # Replace with your CSV path
compute_averages_and_sum(csv_path)
# Out:
# Average Training Accuracy: 0.9996657431125641
# Average Training Loss: 0.0019384132097948002
# Average Training F1 Score: 0.9996662414073945
# Average Validation Accuracy: 0.7822998267412186
# Average Validation Loss: 3.6091335809230802
# Average Validation F1 Score: 0.7823225826025009
# Total Training Time (seconds): 11414.196429729462

# %%
"""
Train Model
"""
def train_model(train_dir,validation_dir,test_dir):

    # Define ImageDataGenerators for training, validation and testing
    # This will handle preprocessing, image augmentation, and splitting.
    datagen = ImageDataGenerator(rescale=1. / 255)

    train_generator = datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')

    validation_generator = datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')

    test_generator = datagen.flow_from_directory(
        test_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')

    # Create the model architecture.
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(len(train_generator.class_indices), activation='softmax'))

    # Compile the model.
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model.
    model.fit(train_generator, validation_data=validation_generator, epochs=1, batch_size=32)

    # Save the model for later use.
    model.save('model.h5')

    compute_f1_score(test_generator,model)

    return train_generator, validation_generator, test_generator, model



train_generator, validation_generator, test_generator, model = train_model\
    ("data/train",
     "data/val",
     "data/test")
# Out:
# Found 5351 images belonging to 2 classes.
# Found 324 images belonging to 2 classes.
# Found 829 images belonging to 2 classes.
# Epoch 1/100
# 168/168 [==============================] - 82s 487ms/step - loss: 0.2715 - accuracy: 0.8972 - val_loss: 0.5484 - val_accuracy: 0.8148
# Epoch 2/100
# 168/168 [==============================] - 81s 481ms/step - loss: 0.1380 - accuracy: 0.9512 - val_loss: 0.3896 - val_accuracy: 0.8889
# Epoch 3/100
# 168/168 [==============================] - 79s 472ms/step - loss: 0.0820 - accuracy: 0.9680 - val_loss: 0.9732 - val_accuracy: 0.7809
# Epoch 4/100
# 118/168 [====================>.........] - ETA: 23s - loss: 0.0420 - accuracy: 0.9845
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 54
#      48     compute_f1_score(test_generator,model)
#      50     return train_generator, validation_generator, test_generator, model
# ---> 54 train_generator, validation_generator, test_generator, model = train_model\
#      55     ("data/train",
#      56      "data/val",
#      57      "data/test")
#
# Cell In[53], line 42, in train_model(train_dir, validation_dir, test_dir)
#      39 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#      41 # Train the model.
# ---> 42 model.fit(train_generator, validation_data=validation_generator,
#      43           epochs=100, batch_size=32)
#      45 # Save the model for later use.
#      46 model.save('model.h5')
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.utils import plot_model

# Assuming your model is defined and named "model"
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras.layers import Input

visible1 = Input(shape=(150, 150, 3))
visible2 = Input(shape=(150, 150, 3))

# Architecture for visible1
x1 = Conv2D(32, (3, 3), activation='relu')(visible1)
x1 = MaxPooling2D(pool_size=(2, 2))(x1)
x1 = Conv2D(64, (3, 3), activation='relu')(x1)
x1 = MaxPooling2D(pool_size=(2, 2))(x1)
x1 = Flatten()(x1)
x1 = Dense(128, activation='relu')(x1)

# Architecture for visible2
x2 = Conv2D(32, (3, 3), activation='relu')(visible2)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x2 = Conv2D(64, (3, 3), activation='relu')(x2)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x2 = Flatten()(x2)
x2 = Dense(128, activation='relu')(x2)

from tensorflow.keras.layers import concatenate

merged = concatenate([x1, x2])
output = Dense(len(train_generator.class_indices), activation='softmax')(merged)


from tensorflow.keras.models import Model

model = Model(inputs=[visible1, visible2], outputs=output)

# %%
# merge input models
merge = concatenate([dense1, dense2])
output = Dense(1)(merge)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # merge input models
# ----> 2 merge = concatenate([dense1, dense2])
#       3 output = Dense(1)(merge)
#
# NameError: name 'dense1' is not defined

# %%
"""
Weapon detection in video
"""

def predict_weapon_video(video_path):
    # Open the video file
    video = cv2.VideoCapture(video_path)

    while(video.isOpened()):
        # Read a frame
        ret, frame = video.read()
        if not ret:
            break

        # Convert the frame color
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Resize the frame to the size your model expects
        resized_frame = cv2.resize(frame_rgb, (150, 150))

        # Normalize the frame
        normalized_frame = resized_frame / 255.0

        # Expand dimensions to match the shape the model expects
        frame_expanded = np.expand_dims(normalized_frame, axis=0)

        # Use the model to predict the weapon
        prediction = model.predict(frame_expanded)
        label = np.argmax(prediction)

        # Get the label name from the train generator's class_indices
        label_name = list(train_generator.class_indices.keys())[
            list(train_generator.class_indices.values()).index(label)]

        print(f"Label: {label_name} - Prediction: {prediction}")
        # Add a label to the frame
        cv2.putText(frame, label_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        # Display the frame
        cv2.imshow('Video', frame)

        # Break the loop on 'q' press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything is done, release the video capture and video write objects
    video.release()

    # Close all the frames
    cv2.destroyAllWindows()

# predict_weapon_video('C:/Users/mupaj/Documents/Apps/final_vc/data/pexels'
#                    '-karolina-grabowska-5243196-1920x1080-25fps.mp4')

# predict_weapon_video('C:/Users/mupaj/Documents/Apps/final_vc/data/pexels-erica-hotaru-5933320-1920x1080-50fps.mp4')
predict_weapon_video('C:/Users/mupaj/Documents/Apps/final_vc/data/180925_02_01_preview.mp4')
# Out:
# 1/1 [==============================] - 0s 62ms/step
# Label: knife - Prediction: [[0.91997945 0.08002057]]
# 1/1 [==============================] - 0s
ms/step
# Label: knife - Prediction: [[0.91997945 0.08002057]]
# 1/1 [==============================] - 0s 29ms/step
# Label: knife - Prediction: [[0.91997945 0.08002057]]
# 1/1 [==============================] - 0s 29ms/step
# Label: knife - Prediction: [[0.9792154  0.02078458]]
# 1/1 [==============================] - 0s 27ms/step
# Label: pistol - Prediction: [[1.3808110e-04 9.9986196e-01]]
# 1/1 [==============================] - 0s 32ms/step
# Label: pistol - Prediction: [[3.1445771e-07 9.9999964e-01]]
# 1/1 [==============================] - 0s 34ms/step
# Label: pistol - Prediction: [[3.2709268e-16 1.0000000e+00]]
# 1/1 [==============================] - 0s 30ms/step
# Label: pistol - Prediction: [[0.3437723 0.6562277]]
# 1/1 [==============================] - 0s 36ms/step
# Label: pistol - Prediction: [[2.2490212e-08 1.0000000e+00]]
# 1/1 [==============================] - 0s 29ms/step
# Label: knife - Prediction: [[0.9988121  0.00118798]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 56
#      50     cv2.destroyAllWindows()
#      52 # predict_weapon_video('C:/Users/mupaj/Documents/Apps/final_vc/data/pexels'
#      53 #                    '-karolina-grabowska-5243196-1920x1080-25fps.mp4')
#      54
#      55 # predict_weapon_video('C:/Users/mupaj/Documents/Apps/final_vc/data/pexels-erica-hotaru-5933320-1920x1080-50fps.mp4')
# ---> 56 predict_weapon_video('C:/Users/mupaj/Documents/Apps/final_vc/data/180925_02_01_preview.mp4')
#
# Cell In[23], line 28, in predict_weapon_video(video_path)
#      25 frame_expanded = np.expand_dims(normalized_frame, axis=0)
#      27 # Use the model to predict the weapon
# ---> 28 prediction = model.predict(frame_expanded)
#      29 label = np.argmax(prediction)
#      31 # Get the label name from the train generator's class_indices
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\keras\engine\training.py:2349, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2340     except ValueError:
#    2341         warnings.warn(
#    2342             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2343             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2346             stacklevel=2,
#    2347         )
# -> 2349 data_handler = data_adapter.get_data_handler(
#    2350     x=x,
#    2351     batch_size=batch_size,
#    2352     steps_per_epoch=steps,
#    2353     initial_epoch=0,
#    2354     epochs=1,
#    2355     max_queue_size=max_queue_size,
#    2356     workers=workers,
#    2357     use_multiprocessing=use_multiprocessing,
#    2358     model=self,
#    2359     steps_per_execution=self._steps_per_execution,
#    2360 )
#    2362 # Container that configures and calls `tf.keras.Callback`s.
#    2363 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\keras\engine\data_adapter.py:1583, in get_data_handler(*args, **kwargs)
#    1581 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1582     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1583 return DataHandler(*args, **kwargs)
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\keras\engine\data_adapter.py:1260, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1257     self._steps_per_execution = steps_per_execution
#    1259 adapter_cls = select_data_adapter(x, y)
# -> 1260 self._adapter = adapter_cls(
#    1261     x,
#    1262     y,
#    1263     batch_size=batch_size,
#    1264     steps=steps_per_epoch,
#    1265     epochs=epochs - initial_epoch,
#    1266     sample_weights=sample_weight,
#    1267     shuffle=shuffle,
#    1268     max_queue_size=max_queue_size,
#    1269     workers=workers,
#    1270     use_multiprocessing=use_multiprocessing,
#    1271     distribution_strategy=tf.distribute.get_strategy(),
#    1272     model=model,
#    1273 )
#    1275 strategy = tf.distribute.get_strategy()
#    1277 self._current_step = 0
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\keras\engine\data_adapter.py:346, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     343         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     344     return flat_dataset
# --> 346 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     348 dataset = self.slice_inputs(indices_dataset, inputs)
#     350 if shuffle == "batch":
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2285, in DatasetV2.flat_map(self, map_func, name)
#    2281 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2282 # dataset_ops).
#    2283 # pylint: disable=g-import-not-at-top,protected-access
#    2284 from tensorflow.python.data.ops import flat_map_op
# -> 2285 return flat_map_op._flat_map(self, map_func, name=name)
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:33, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      30 def __init__(self, input_dataset, map_func, name=None):
#      32   self._input_dataset = input_dataset
# ---> 33   self._map_func = structured_function.StructuredFunctionWrapper(
#      34       map_func, self._transformation_name(), dataset=input_dataset)
#      35   if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#      36     raise TypeError(
#      37         "The `map_func` argument must return a `Dataset` object. Got "
#      38         f"{dataset_ops.get_type(self._map_func.output_structure)!r}.")
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\data\ops\structured_function.py:261, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     254       warnings.warn(
#     255           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     256           "option is set, this option does not apply to tf.data functions. "
#     257           "To force eager execution of tf.data functions, please use "
#     258           "`tf.data.experimental.enable_debug_mode()`.")
#     259     fn_factory = trace_tf_function(defun_kwargs)
# --> 261 self._function = fn_factory()
#     262 # There is no graph to add in eager mode.
#     263 add_to_graph &= not context.executing_eagerly()
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:232, in TracingCompiler.get_concrete_function(self, *args, **kwargs)
#     223 def get_concrete_function(self, *args, **kwargs):
#     224   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#     225
#     226   Args:
#    (...)
#     230       `tf.Tensor` or `tf.TensorSpec`.
#     231   """
# --> 232   concrete_function = self._get_concrete_function_garbage_collected(
#     233       *args, **kwargs)
#     234   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#     235   return concrete_function
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:202, in TracingCompiler._get_concrete_function_garbage_collected(self, *args, **kwargs)
#     199   self._function_spec.make_canonicalized_monomorphic_type(args, kwargs)
#     201 with self._lock:
# --> 202   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     203   seen_names = set()
#     204   concrete_function._arg_keywords = []  # pylint: disable=protected-access
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:166, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     163   args = self.input_signature
#     164   kwargs = {}
# --> 166 return self._maybe_define_function(args, kwargs)
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:396, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     393   args = placeholder_bound_args.args
#     394 kwargs = placeholder_bound_args.kwargs
# --> 396 concrete_function = self._create_concrete_function(
#     397     args, kwargs, func_graph)
#     399 # TODO(b/263520817): Remove access to private attribute.
#     400 graph_capture_container = concrete_function.graph._function_captures  # pylint: disable=protected-access
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:299, in TracingCompiler._create_concrete_function(self, args, kwargs, func_graph)
#     296 else:
#     297   arg_names = base_arg_names
# --> 299 concrete_function = monomorphic_function.ConcreteFunction(
#     300     func_graph_module.func_graph_from_py_func(
#     301         self._name,
#     302         self._python_function,
#     303         args,
#     304         kwargs,
#     305         None,
#     306         func_graph=func_graph,
#     307         autograph=self._autograph,
#     308         autograph_options=self._autograph_options,
#     309         arg_names=arg_names,
#     310         capture_by_value=self._capture_by_value,
#     311         create_placeholders=False),
#     312     self._function_attributes,
#     313     spec=self.function_spec,
#     314     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     315     # scope. This is not the default behavior since it gets used in some
#     316     # places (like Keras) where the FuncGraph lives longer than the
#     317     # ConcreteFunction.
#     318     shared_func_graph=False)
#     319 return concrete_function
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1362, in ConcreteFunction.__init__(self, func_graph, attrs, shared_func_graph, spec)
#    1356   self._garbage_collector = ConcreteFunctionGarbageCollector(func_graph)
#    1358 # Pairs of forward and backward functions used for computing gradients.
#    1359 #
#    1360 # These each get a reference to the FuncGraph deleter since they use the
#    1361 # FuncGraph directly.
# -> 1362 self._delayed_rewrite_functions = _DelayedRewriteGradientFunctions(
#    1363     func_graph, self._attrs, self._garbage_collector)
#    1364 self._first_order_tape_functions = {}
#    1365 self._higher_order_tape_functions = {}
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:466, in _DelayedRewriteGradientFunctions.__init__(self, func_graph, attrs, func_graph_deleter)
#     464 self._cached_function_pairs = {}
#     465 self._func_graph = func_graph
# --> 466 self._inference_function = _EagerDefinedFunction(
#     467     _inference_name(self._func_graph.name), self._func_graph,
#     468     self._func_graph.inputs, self._func_graph.outputs, attrs)
#     469 self._attrs = attrs
#     470 self._gradient_name = None
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:252, in _EagerDefinedFunction.__init__(self, name, graph, inputs, outputs, attrs)
#     246   pywrap_tf_session.TF_FunctionSetAttrValueProto(fn, compat.as_str(name),
#     247                                                  serialized)
#     249 # NOTE(feyu): Do not cache signature and definition at initialization to
#     250 # save memory usage of concrete functions never called through Python. We
#     251 # cache them on the first call of .definition and .signature.
# --> 252 signature = self._get_definition().signature
#     254 self._name = compat.as_bytes(signature.name)
#     255 with ops.init_scope():
#
# File ~\Documents\Apps\final_vc\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:295, in _EagerDefinedFunction._get_definition(self)
#     293 with c_api_util.tf_buffer() as buffer_:
#     294   with self._c_func.get() as func:
# --> 295     pywrap_tf_session.TF_FunctionToFunctionDef(func, buffer_)
#     296   proto_data = pywrap_tf_session.TF_GetBuffer(buffer_)
#     297 function_def = function_pb2.FunctionDef()
#
# KeyboardInterrupt:
