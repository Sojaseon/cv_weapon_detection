# %%
ROOT_RESULTS_2 = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/FINAL" \
                 "/results2/"
DATASET = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/data/big" \
          "/weapons/weapon_detection/train/augmented_2"
DATASET_TEST = "C:/Users/mupaj/Documents/Apps/cv_weapon_detection/FINAL" \
           "/test_model/"

import math

num_epochs = 100

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

def save_matrix_to_csv(conf_matrix, epoch, filename=None):
    if filename is None:
        filename = f"{ROOT_RESULTS_2}confusion_matrices.csv"

    # Convert matrix to DataFrame for easier CSV storage
    df = pd.DataFrame(conf_matrix)

    # Add a column to specify the epoch number
    df['epoch'] = epoch

    # If file doesn't exist, create one. Otherwise, append without writing the header again.
    if not os.path.isfile(filename):
        df.to_csv(filename, index=False)
    else:
        df.to_csv(filename, mode='a', header=False, index=False)

def plot_combined_confusion_matrices_from_csv(labels, filename=None):
    if filename is None:
        filename = f"{ROOT_RESULTS_2}confusion_matrices.csv"

    # Read the saved CSV
    data = pd.read_csv(filename)

    total_epochs = data['epoch'].nunique()

    plt.figure(figsize=(15, 7*total_epochs))

    for i, epoch in enumerate(data['epoch'].unique()):
        conf_matrix = data[data['epoch'] == epoch].drop('epoch', axis=1).values
        plt.subplot(total_epochs, 1, i+1)
        sns.heatmap(conf_matrix, annot=True, cmap="YlGnBu", fmt="g",
                    xticklabels=labels, yticklabels=labels)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title(f'Confusion Matrix - Epoch {epoch}')

    plt.tight_layout()
    plt.savefig(f'{ROOT_RESULTS_2}combined_confusion_matrices.png')
    plt.show()

# %%
# Imports
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
import time
import csv
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import backend as K
import tensorflow as tf
tf.compat.v1.reset_default_graph()

train_accs, val_accs, train_losses, val_losses = [], [], [], []
all_confusion_matrices = []

# F1 Metric
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

def train_model(dataset_dir):

    # ImageDataGenerator for data augmentation and rescaling
    datagen = ImageDataGenerator(rescale=1. / 255, validation_split=0.2)  # assuming 20% validation split

    train_generator = datagen.flow_from_directory(
        dataset_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical',
        subset='training',
        seed=42)  # reproducible split

    validation_generator = datagen.flow_from_directory(
        dataset_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical',
        subset='validation',
        seed=42)  # reproducible split

    from keras.models import Sequential
    from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

    # Create AlexNet-equivalent model
    model = Sequential()

    # 1st Conv Layer
    model.add(Conv2D(96, (11, 11), strides=(4, 4), activation='relu', padding='valid', input_shape=(150, 150, 3)))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

    # 2nd Conv Layer
    model.add(Conv2D(256, (5, 5), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

    # 3rd Conv Layer
    model.add(Conv2D(384, (3, 3), activation='relu', padding='same'))

    # 4th Conv Layer
    model.add(Conv2D(384, (3, 3), activation='relu', padding='same'))

    # 5th Conv Layer
    model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

    # Flatten
    model.add(Flatten())

    # 1st FC Layer
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))

    # 2nd FC Layer
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))

    # 3rd FC Layer
    model.add(Dense(len(train_generator.class_indices), activation='softmax'))

    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', f1_score])




    # CSV for results
    with open(f"{ROOT_RESULTS_2}results.csv", "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Epoch", "Accuracy", "Loss", "F1 Score", "Validation Accuracy", "Validation Loss", "Validation F1 Score", "Time (seconds)"])

        # Initialize a combined confusion matrix with zeros
        combined_conf_matrix = np.zeros((len(train_generator.class_indices), len(train_generator.class_indices)))

        # Training and data collection for 5 epochs
        for epoch in range(1, num_epochs+1):
            start_time = time.time()
            history = model.fit(train_generator, validation_data=validation_generator, epochs=epoch, initial_epoch=epoch-1, batch_size=32, verbose=1)
            end_time = time.time()

            train_accs.append(history.history['accuracy'][-1])
            val_accs.append(history.history['val_accuracy'][-1])
            train_losses.append(history.history['loss'][-1])
            val_losses.append(history.history['val_loss'][-1])

            # Saving epoch data to CSV including F1 score
            writer.writerow([epoch,
                             history.history['accuracy'][-1],
                             history.history['loss'][-1],
                             history.history['f1_score'][-1],
                             history.history['val_accuracy'][-1],
                             history.history['val_loss'][-1],
                             history.history['val_f1_score'][-1],
                             end_time - start_time])

            # Reset validation generator and predict
            validation_generator.reset()
            predictions = model.predict(validation_generator)
            y_pred = np.argmax(predictions, axis=1)
            y_true = validation_generator.classes

            # Compute the confusion matrix
            conf_matrix = confusion_matrix(y_true, y_pred)
            combined_conf_matrix += conf_matrix

    # PLOTTING ACCURACY AND LOSS
    # Plotting accuracy and loss after all epochs
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(train_accs, label='Train Accuracy')
    plt.plot(val_accs, label='Validation Accuracy')
    plt.legend()
    plt.title(f"Total Epochs {epoch} Accuracy")

    plt.subplot(1, 2, 2)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.legend()
    plt.title(f"Total Epochs {epoch} Loss")

    plt.savefig(f"{ROOT_RESULTS_2}total_epochs_plot.png")
    plt.show()

    # CONFUSION MATRIX
    # Plot the combined confusion matrix
    plt.figure(figsize=(10, 7))
    sns.heatmap(combined_conf_matrix, annot=True, cmap="YlGnBu", fmt="g",
                xticklabels=list(train_generator.class_indices.keys()),
                yticklabels=list(train_generator.class_indices.keys()))
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Combined Confusion Matrix Over All Epochs')
    plt.savefig(f'{ROOT_RESULTS_2}combined_confusion_matrix.png')
    plt.show()

    # Save the final model
    model.save(f'{ROOT_RESULTS_2}model_resuilts_2.h5')

    return train_generator, validation_generator, model

# Usage (Make sure ROOT_RESULTS_2 is defined)

train_generator, validation_generator, model = train_model(DATASET)
# Out:
# Found 9394 images belonging to 2 classes.
# Found 2348 images belonging to 2 classes.
# 294/294 [==============================] - 197s 667ms/step - loss: 0.6974 - accuracy: 0.4930 - f1_score: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 70ms/step
# Epoch 2/2
# 294/294 [==============================] - 196s 666ms/step - loss: 0.6934 - accuracy: 0.4932 - f1_score: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.4993
# 74/74 [==============================] - 5s 68ms/step
# Epoch 3/3
# 294/294 [==============================] - 188s 640ms/step - loss: 0.6934 - accuracy: 0.4950 - f1_score: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s
- val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 71ms/step
# Epoch 52/52
# 294/294 [==============================] - 183s 624ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5020 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 71ms/step
# Epoch 53/53
# 294/294 [==============================] - 183s 624ms/step - loss: 0.6932 - accuracy: 0.4951 - f1_score: 0.4950 - val_loss: 0.6932 - val_accuracy: 0.4979 - val_f1_score: 0.4993
# 74/74 [==============================] - 5s 69ms/step
# Epoch 54/54
# 294/294 [==============================] - 183s 622ms/step - loss: 0.6932 - accuracy: 0.4913 - f1_score: 0.4914 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5042
# 74/74 [==============================] - 5s 68ms/step
# Epoch 55/55
# 294/294 [==============================] - 183s 621ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5022 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5000
# 74/74 [==============================] - 5s 69ms/step
# Epoch 56/56
# 294/294 [==============================] - 183s 621ms/step - loss: 0.6932 - accuracy: 0.4966 - f1_score: 0.4964 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 69ms/step
# Epoch 57/57
# 294/294 [==============================] - 182s 621ms/step - loss: 0.6932 - accuracy: 0.5002 - f1_score: 0.5002 - val_loss: 0.6932 - val_accuracy: 0.5021 - val_f1_score: 0.5007
# 74/74 [==============================] - 5s 70ms/step
# Epoch 58/58
# 294/294 [==============================] - 183s 622ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5021 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5007
# 74/74 [==============================] - 5s 70ms/step
# Epoch 59/59
# 294/294 [==============================] - 183s 622ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5024 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 70ms/step
# Epoch 60/60
# 294/294 [==============================] - 184s 625ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5021 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5042
# 74/74 [==============================] - 5s 68ms/step
# Epoch 61/61
# 294/294 [==============================] - 182s 619ms/step - loss: 0.6932 - accuracy: 0.4904 - f1_score: 0.4904 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5000
# 74/74 [==============================] - 5s 67ms/step
# Epoch 62/62
# 294/294 [==============================] - 183s 622ms/step - loss: 0.6932 - accuracy: 0.4936 - f1_score: 0.4936 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5014
# 74/74 [==============================] - 5s 68ms/step
# Epoch 63/63
# 294/294 [==============================] - 184s 626ms/step - loss: 0.6932 - accuracy: 0.5011 - f1_score: 0.5013 - val_loss: 0.6932 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 68ms/step
# Epoch 64/64
# 294/294 [==============================] - 182s 620ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5020 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5014
# 74/74 [==============================] - 5s 70ms/step
# Epoch 65/65
# 294/294 [==============================] - 185s 628ms/step - loss: 0.6932 - accuracy: 0.5002 - f1_score: 0.5001 - val_loss: 0.6932 - val_accuracy: 0.4979 - val_f1_score: 0.4986
# 74/74 [==============================] - 5s 70ms/step
# Epoch 66/66
# 294/294 [==============================] - 183s 622ms/step - loss: 0.6932 - accuracy: 0.4868 - f1_score: 0.4869 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 69ms/step
# Epoch 67/67
# 294/294 [==============================] - 182s 620ms/step - loss: 0.6932 - accuracy: 0.4951 - f1_score: 0.4949 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 70ms/step
# Epoch 68/68
# 294/294 [==============================] - 183s 622ms/step - loss: 0.6932 - accuracy: 0.4934 - f1_score: 0.4933 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 69ms/step
# Epoch 69/69
# 294/294 [==============================] - 182s 621ms/step - loss: 0.6932 - accuracy: 0.4913 - f1_score: 0.4911 - val_loss: 0.6932 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 69ms/step
# Epoch 70/70
# 294/294 [==============================] - 183s 621ms/step - loss: 0.6932 - accuracy: 0.4994 - f1_score: 0.4995 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5007
# 74/74 [==============================] - 5s 68ms/step
# Epoch 71/71
# 294/294 [==============================] - 183s 624ms/step - loss: 0.6932 - accuracy: 0.4989 - f1_score: 0.4990 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5014
# 74/74 [==============================] - 5s 69ms/step
# Epoch 72/72
# 294/294 [==============================] - 183s 622ms/step - loss: 0.6932 - accuracy: 0.5009 - f1_score: 0.5009 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 70ms/step
# Epoch 73/73
# 294/294 [==============================] - 182s 619ms/step - loss: 0.6932 - accuracy: 0.4970 - f1_score: 0.4970 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 73ms/step
# Epoch 74/74
# 294/294 [==============================] - 182s 618ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5020 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 69ms/step
# Epoch 75/75
# 294/294 [==============================] - 185s 627ms/step - loss: 0.6932 - accuracy: 0.4968 - f1_score: 0.4968 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5007
# 74/74 [==============================] - 5s 72ms/step
# Epoch 76/76
# 294/294 [==============================] - 192s 652ms/step - loss: 0.6932 - accuracy: 0.4953 - f1_score: 0.4952 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5014
# 74/74 [==============================] - 6s 75ms/step
# Epoch 77/77
# 294/294 [==============================] - 189s 645ms/step - loss: 0.6932 - accuracy: 0.4974 - f1_score: 0.4977 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 73ms/step
# Epoch 78/78
# 294/294 [==============================] - 192s 652ms/step - loss: 0.6932 - accuracy: 0.4979 - f1_score: 0.4975 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 69ms/step
# Epoch 79/79
# 294/294 [==============================] - 189s 643ms/step - loss: 0.6932 - accuracy: 0.4943 - f1_score: 0.4943 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5042
# 74/74 [==============================] - 6s 74ms/step
# Epoch 80/80
# 294/294 [==============================] - 182s 618ms/step - loss: 0.6932 - accuracy: 0.4972 - f1_score: 0.4971 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5007
# 74/74 [==============================] - 5s 70ms/step
# Epoch 81/81
# 294/294 [==============================] - 178s 606ms/step - loss: 0.6932 - accuracy: 0.4955 - f1_score: 0.4954 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5007
# 74/74 [==============================] - 5s 67ms/step
# Epoch 82/82
# 294/294 [==============================] - 179s 608ms/step - loss: 0.6933 - accuracy: 0.4904 - f1_score: 0.4900 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5014
# 74/74 [==============================] - 5s 69ms/step
# Epoch 83/83
# 294/294 [==============================] - 179s 610ms/step - loss: 0.6932 - accuracy: 0.4964 - f1_score: 0.4964 - val_loss: 0.6932 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 69ms/step
# Epoch 84/84
# 294/294 [==============================] - 179s 609ms/step - loss: 0.6932 - accuracy: 0.4957 - f1_score: 0.4957 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 71ms/step
# Epoch 85/85
# 294/294 [==============================] - 179s 608ms/step - loss: 0.6932 - accuracy: 0.4987 - f1_score: 0.4990 - val_loss: 0.6932 - val_accuracy: 0.4979 - val_f1_score: 0.4965
# 74/74 [==============================] - 5s 70ms/step
# Epoch 86/86
# 294/294 [==============================] - 178s 607ms/step - loss: 0.6932 - accuracy: 0.5006 - f1_score: 0.5007 - val_loss: 0.6932 - val_accuracy: 0.4979 - val_f1_score: 0.4979
# 74/74 [==============================] - 5s 71ms/step
# Epoch 87/87
# 294/294 [==============================] - 178s 606ms/step - loss: 0.6932 - accuracy: 0.5026 - f1_score: 0.5027 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5014
# 74/74 [==============================] - 5s 69ms/step
# Epoch 88/88
# 294/294 [==============================] - 179s 609ms/step - loss: 0.6932 - accuracy: 0.4985 - f1_score: 0.4986 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 71ms/step
# Epoch 89/89
# 294/294 [==============================] - 181s 616ms/step - loss: 0.6932 - accuracy: 0.4994 - f1_score: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5035
# 74/74 [==============================] - 5s 69ms/step
# Epoch 90/90
# 294/294 [==============================] - 179s 609ms/step - loss: 0.6932 - accuracy: 0.4985 - f1_score: 0.4986 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5007
# 74/74 [==============================] - 5s 69ms/step
# Epoch 91/91
# 294/294 [==============================] - 184s 625ms/step - loss: 0.6932 - accuracy: 0.4940 - f1_score: 0.4940 - val_loss: 0.6932 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 6s 76ms/step
# Epoch 92/92
# 294/294 [==============================] - 184s 625ms/step - loss: 0.6932 - accuracy: 0.5004 - f1_score: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.5021 - val_f1_score: 0.5007
# 74/74 [==============================] - 5s 72ms/step
# Epoch 93/93
# 294/294 [==============================] - 187s 635ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5021 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 70ms/step
# Epoch 94/94
# 294/294 [==============================] - 178s 606ms/step - loss: 0.6932 - accuracy: 0.5021 - f1_score: 0.5020 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5000
# 74/74 [==============================] - 5s 68ms/step
# Epoch 95/95
# 294/294 [==============================] - 177s 602ms/step - loss: 0.6931 - accuracy: 0.5032 - f1_score: 0.5031 - val_loss: 0.6932 - val_accuracy: 0.4979 - val_f1_score: 0.4986
# 74/74 [==============================] - 5s 70ms/step
# Epoch 96/96
# 294/294 [==============================] - 177s 603ms/step - loss: 0.6932 - accuracy: 0.4921 - f1_score: 0.4920 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 70ms/step
# Epoch 97/97
# 294/294 [==============================] - 176s 598ms/step - loss: 0.6932 - accuracy: 0.4955 - f1_score: 0.4958 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 68ms/step
# Epoch 98/98
# 294/294 [==============================] - 180s 614ms/step - loss: 0.6932 - accuracy: 0.4932 - f1_score: 0.4934 - val_loss: 0.6931 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 69ms/step
# Epoch 99/99
# 294/294 [==============================] - 176s 600ms/step - loss: 0.6932 - accuracy: 0.5006 - f1_score: 0.5007 - val_loss: 0.6932 - val_accuracy: 0.5021 - val_f1_score: 0.5028
# 74/74 [==============================] - 5s 70ms/step
# Epoch 100/100
# 294/294 [==============================] - 176s 600ms/step - loss: 0.6932 - accuracy: 0.4957 - f1_score: 0.4956 - val_loss: 0.6932 - val_accuracy: 0.5021 - val_f1_score: 0.5021
# 74/74 [==============================] - 5s 68ms/step
# C:\Users\mupaj\Documents\Apps\cv_weapon_detection\venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
